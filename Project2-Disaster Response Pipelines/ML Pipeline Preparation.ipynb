# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import re

import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet') # download for lemmatization

from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline,FeatureUnion

from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import classification_report

stop_words = stopwords.words("english")
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql(sql='select * from DisasterResponse',con=engine)
X = df.message.values
Y = df.iloc[:,3:]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    # normalize case and remove punctuation
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())
    
    # tokenize text
    tokens = word_tokenize(text)
    
    # lemmatize andremove stop words
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]

    return tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# - You'll find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(estimator=RandomForestClassifier(),n_jobs=-1))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)
# pipeline.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...ob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=-1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
# y_pred = pipeline.predict(X_test)

# y_pred_df = pd.DataFrame(y_pred,columns=Y.columns,index=range(y_pred.shape[0]))
# y_test_df = pd.DataFrame(y_test,columns=Y.columns,index=range(y_pred.shape[0]))
# y_test_df.fillna(0,inplace=True)
# y_test_df = y_test_df.applymap(lambda x:int(x))

# for column in y_pred_df.columns:
#     curr_f1_report = classification_report(y_test_df[[column]],y_pred_df[[column]])
# #     print(y_test_df[[column]],y_pred_df[[column]])
# #     ,target_names=['%s-True' %column,'%s-False' %column]
#     print("*"*80)
#     print("f1 score for '%s' column:\n" %column)
#     print(curr_f1_report)
# Out:
# ********************************************************************************
# f1 score for 'related' column:
#
#              precision    recall  f1-score   support
#
#           0       0.80      0.17      0.28      5326
#           1       0.18      0.80      0.30      1218
#           2       0.00      0.00      0.00        10
#
# avg / total       0.68      0.29      0.28      6554
#
# ********************************************************************************
# f1 score for 'request' column:
#
#              precision    recall  f1-score   support
#
#           0       0.89      0.91      0.90      5813
#           1       0.10      0.08      0.09       741
#
# avg / total       0.80      0.81      0.80      6554
#
# ********************************************************************************
# f1 score for 'offer' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6552
#           1       0.00      0.00      0.00         2
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'aid_related' column:
#
#              precision    recall  f1-score   support
#
#           0       0.88      0.65      0.75      5752
#           1       0.12      0.35      0.18       802
#
# avg / total       0.79      0.62      0.68      6554
#
# ********************************************************************************
# f1 score for 'medical_help' column:
#
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6453
#           1       0.04      0.03      0.03       101
#
# avg / total       0.97      0.97      0.97      6554
#
# ********************************************************************************
# f1 score for 'medical_products' column:
#
#              precision    recall  f1-score   support
#
#           0       0.99      0.99      0.99      6489
#           1       0.04      0.03      0.03        65
#
# avg / total       0.98      0.98      0.98      6554
#
# ********************************************************************************
# f1 score for 'search_and_rescue' column:
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6518
#           1       0.00      0.00      0.00        36
#
# avg / total       0.99      0.99      0.99      6554
#
# ********************************************************************************
# f1 score for 'security' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6526
#           1       0.00      0.00      0.00        28
#
# avg / total       0.99      1.00      0.99      6554
#
# ********************************************************************************
# f1 score for 'military' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6544
#           1       0.00      0.00      0.00        10
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'child_alone' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'water' column:
#
#              precision    recall  f1-score   support
#
#           0       0.97      0.98      0.98      6366
#           1       0.03      0.02      0.02       188
#
# avg / total       0.94      0.96      0.95      6554
#
# ********************************************************************************
# f1 score for 'food' column:
#
#              precision    recall  f1-score   support
#
#           0       0.95      0.93      0.94      6223
#           1       0.05      0.07      0.06       331
#
# avg / total       0.90      0.89      0.89      6554
#
# ********************************************************************************
# f1 score for 'shelter' column:
#
#              precision    recall  f1-score   support
#
#           0       0.97      0.96      0.96      6343
#           1       0.04      0.05      0.05       211
#
# avg / total       0.94      0.93      0.93      6554
#
# ********************************************************************************
# f1 score for 'clothing' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6530
#           1       0.00      0.00      0.00        24
#
# avg / total       0.99      0.99      0.99      6554
#
# ********************************************************************************
# f1 score for 'money' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6533
#           1       0.00      0.00      0.00        21
#
# avg / total       0.99      1.00      0.99      6554
#
# ********************************************************************************
# f1 score for 'missing_people' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6537
#           1       0.00      0.00      0.00        17
#
# avg / total       0.99      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'refugees' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6522
#           1       0.00      0.00      0.00        32
#
# avg / total       0.99      0.99      0.99      6554
#
# ********************************************************************************
# f1 score for 'death' column:
#
#              precision    recall  f1-score   support
#
#           0       0.99      0.99      0.99      6495
#           1       0.00      0.00      0.00        59
#
# avg / total       0.98      0.98      0.98      6554
#
# ********************************************************************************
# f1 score for 'other_aid' column:
#
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      6276
#           1       0.09      0.03      0.04       278
#
# avg / total       0.92      0.95      0.93      6554
#
# ********************************************************************************
# f1 score for 'infrastructure_related' column:
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6504
#           1       0.00      0.00      0.00        50
#
# avg / total       0.98      0.99      0.99      6554
#
# ********************************************************************************
# f1 score for 'transport' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6527
#           1       0.00      0.00      0.00        27
#
# avg / total       0.99      0.99      0.99      6554
#
# ********************************************************************************
# f1 score for 'buildings' column:
#
#              precision    recall  f1-score   support
#
#           0       0.99      0.99      0.99      6482
#           1       0.00      0.00      0.00        72
#
# avg / total       0.98      0.98      0.98      6554
#
# ********************************************************************************
# f1 score for 'electricity' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6542
#           1       0.00      0.00      0.00        12
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'tools' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6546
#           1       0.00      0.00      0.00         8
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'hospitals' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6544
#           1       0.00      0.00      0.00        10
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'shops' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6547
#           1       0.00      0.00      0.00         7
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'aid_centers' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6545
#           1       0.00      0.00      0.00         9
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'other_infrastructure' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6528
#           1       0.00      0.00      0.00        26
#
# avg / total       0.99      0.99      0.99      6554
#
# ********************************************************************************
# f1 score for 'weather_related' column:
#
#              precision    recall  f1-score   support
#
#           0       0.97      0.80      0.88      6335
#           1       0.04      0.24      0.07       219
#
# avg / total       0.94      0.78      0.85      6554
#
# ********************************************************************************
# f1 score for 'floods' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      0.97      0.98      6527
#           1       0.00      0.04      0.01        27
#
# avg / total       0.99      0.96      0.98      6554
#
# ********************************************************************************
# f1 score for 'storm' column:
#
#              precision    recall  f1-score   support
#
#           0       0.99      0.96      0.97      6515
#           1       0.02      0.13      0.03        39
#
# avg / total       0.99      0.95      0.97      6554
#
# ********************************************************************************
# f1 score for 'fire' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6547
#           1       0.00      0.00      0.00         7
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'earthquake' column:
#
#              precision    recall  f1-score   support
#
#           0       0.98      0.92      0.95      6426
#           1       0.02      0.09      0.04       128
#
# avg / total       0.96      0.90      0.93      6554
#
# ********************************************************************************
# f1 score for 'cold' column:
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6541
#           1       0.00      0.00      0.00        13
#
# avg / total       1.00      1.00      1.00      6554
#
# ********************************************************************************
# f1 score for 'other_weather' column:
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6519
#           1       0.00      0.00      0.00        35
#
# avg / total       0.99      0.99      0.99      6554
#
# ********************************************************************************
# f1 score for 'direct_report' column:
#
#              precision    recall  f1-score   support
#
#           0       0.89      0.92      0.90      5850
#           1       0.11      0.08      0.09       704
#
# avg / total       0.81      0.83      0.82      6554
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters = {
#         'vect__ngram_range': ((1, 1), (1, 2)),
        'vect__max_df': (0.5, 0.75, 1.0),
#         'vect__max_features': (None, 5000, 10000),
#         'tfidf__use_idf': (True, False),
        'clf__estimator__n_estimators': [50, 100, 200],
#         'clf__estimator__min_samples_split': [2, 3, 4]
    }

cv = GridSearchCV(pipeline,param_grid=parameters,n_jobs=-1,verbose=2)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
cv.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
